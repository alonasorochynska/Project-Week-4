# %%
import plotly.express as px

# %%
import plotly.graph_objects as go

# Load data frame and tidy it.
import pandas as pd
df = pd.read_csv('worldcities.csv')

fig = go.Figure(data=go.Choropleth(
    locations=df['city'], # Spatial coordinates
    z = df['population'].astype(float), # Data to be color-coded
    locationmode = 'USA-states', # set of locations match entries in `locations`
    colorscale = 'Reds',
    colorbar_title = "Millions USD",
))

fig.update_layout(
    title_text = '2011 US Agriculture Exports by State',
    geo_scope='usa', # limite map scope to USA
)

fig.show()
# Out:
# <div>
#
#
#             <div id="3d9077dc-b350-4875-8093-76c31b374f7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3d9077dc-b350-4875-8093-76c31b374f7c")) {
#                     Plotly.newPlot(
#                         '3d9077dc-b350-4875-8093-76c31b374f7c',
#                         [{"colorbar": {"title": {"text": "Millions USD"}}, "colorscale": [[0.0, "rgb(255,245,240)"], [0.125, "rgb(254,224,210)"], [0.25, "rgb(252,187,161)"], [0.375, "rgb(252,146,114)"], [0.5, "rgb(251,106,74)"], [0.625, "rgb(239,59,44)"], [0.75, "rgb(203,24,29)"], [0.875, "rgb(165,15,21)"], [1.0, "rgb(103,0,13)"]], "locationmode": "USA-states", "locations": ["Malishev\u00eb", "Prizren", "Zubin Potok", "Kamenic\u00eb", "Viti", "Sht\u00ebrpc\u00eb", "Shtime", "Vushtrri", "Dragash", "Podujev\u00eb", "Fush\u00eb Kosov\u00eb", "Ka\u00e7anik", "Klin\u00eb", "Leposaviq", "Pej\u00eb", "Rahovec", "Gjilan", "Lipjan", "Obiliq", "Gjakov\u00eb", "Pristina", "De\u00e7an", "Istog", "Hani i Elezit", "Junik", "Kllokot", "Mamush\u00eb", "Partesh", "Ranillug", "Ferizaj", "Zve\u00e7an", "Suharek\u00eb", "Gllogovc", "Mitrovic\u00eb", "Skenderaj", "Novob\u00ebrd\u00eb", "Gra\u00e7anic\u00eb", "Longyearbyen", "Al Quds", "Sanaa", "Marib", "Al Jab\u012bn", "Hajjah", "Ibb", "Al Hudaydah", "Lahij", "Al Ma\u1e29w\u012bt", "Taizz", "Sadah", "Dhamar", "\u2018Amr\u0101n", "A\u1e11 \u1e10\u0101li\u2018", "Saywun", "Al Bayda", "Zinjib\u0101r", "Rida", "'Ataq", "Al Ghaydah", "Sayhut", "Al Mukalla", "Al \u1e28azm", "Zab\u012bd", "Aden", "Hadiboh", "Ash Shihr", "Dzaoudzi", "Lebowakgomo", "Potchefstroom", "Graaff Reinet", "Rustenburg", "Brandfort", "Vryheid", "Vereeniging", "Brits", "Bethlehem", "Ubomba", "Polokwane", "Springbok", "Thohoyandou", "Pietermaritzburg", "Poffader", "Carnarvon", "Kroonstad", "Alexander Bay", "Bloemhof", "Hermanus", "Bethal", "Upington", "Tzaneen", "Vanhynsdorp", "Kimberley", "Durban", "Klerksdorp", "Welkom", "De Aar", "Prieska", "Saldanha", "Middelburg", "Port St. Johns", "Volksrust", "Ulundi", "Beaufort West", "Komatipoort", "Nelspruit", "Standerton", "Johannesburg", "Kuruman", "Paarl", "Worcester", "Colesberg", "Umtata", "Aliwal North", "Middelburg", "Springs", "Benoni", "Port Shepstone", "Oudtshoorn", "Port Elizabeth", "Port Alfred", "East London", "Mossel Bay", "Vryburg", "Uitenhage", "Bhisho", "Knysna", "Queenstown", "Cradock", "Bredasdorp", "Swellendam", "Ladysmith", "George", "Grahamstown", "Mmabatho", "Mahikeng", "Musina", "Pretoria", "Bloemfontein", "Cape Town", "Zambezi", "Solwezi", "Lusaka", "Kaoma", "Chipata", "Senanga", "Sesheke", "Chililabombwe", "Chingola", "Kasempa", "Kitwe", "Mufulira", "Nchelenge", "Mazabuka", "Lukulu", "Kafue", "Lundazi", "Mansa", "Mwinilunga", "Mumbwa", "Kalabo", "Nyimba", "Kapiri Mposhi", "Kabwe", "Ndola", "Kasama", "Mbala", "Kawambwa", "Luanshya", "Mongu", "Mpika", "Chinsali", "Livingstone", "Choma", "Plumtree", "Kariba", "Hwange", "Chiredzi", "Mazowe", "Zvishavane", "Shamva", "Harare", "Kwekwe", "Kadoma", "Beitbridge", "Karoi", "Victoria Falls", "Chitungwiza", "Bindura", "Lupane", "Marondera", "Masvingo", "Mutare", "Bulawayo", "Chinhoyi", "Gwanda", "Gweru", "Maqat", "Zhangaozen", "Taraz", "Oral", "Balqash", "Zaysan", "Oytal", "Zholymbet", "Serebryansk", "Chapaev", "Ridder", "Zhaltyr", "Atbasar", "Aqsay", "Shemonaikha", "Atasu", "Rudny", "Makhambet", "Fort Shevchenko", "Qusmuryn", "Oktyabrsk", "Khromtau", "Algha", "Embi", "Ushtobe", "Burylbaytal", "Zhanibek", "Esil", "Derzhavinsk", "Saryshaghan", "Turgay", "Sarqan", "Arqalyq", "Shalqar", "Shieli", "Bayghanin", "Zhezqazghan", "Mangyshlak", "Zhosaly", "Beyneu", "Qazaly", "Aral", "Ayakoz", "Urzhar", "Qapshaghay", "Esik", "Qaratau", "Sharbaqty", "Oostanay", "Kachiry", "Kishkenekol", "Bulaevo", "Shonzhy", "Qyzylorda", "Qaraghandy", "Ertis", "Tayynsha", "Qulan", "Shu", "Kentau", "Oskemen", "Aqtau", "Taldyqorghan", "Astana", "Aqtobe", "Kokshetau", "Petropavlovsk", "Pavlodar", "Otar", "Almaty", "Bestobe", "Arys", "Lenger", "Aqsu", "Temirtau", "Makinsk", "Osakarovka", "Qarqaraly", "Ekibastuz", "Zyryanovsk", "Komsomolets", "Baykonur", "Erymentau", "Qarazhal", "Tobol", "Shar", "Semey", "Boralday", "Zhetiqara", "Aqadyr", "Zharkent", "Qulsary", "Balyqshy", "Atyrau", "Shymkent", "Turkistan", "Xiangkhoang", "Muang Ph\u00f4nsavan", "Vientiane", " ...

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

geo_geo = pd.read_csv("worldcities.csv")

world= world.rename(columns={"name": "Country"})
europe =  world.query('continent == "Europe"')
europe.drop(europe[europe.Country == "Russia"].index, inplace=True)

india =  world.query('Country == "India"')
Polygons = (europe.loc[43].at['geometry'])[1]

europe.loc[europe['Country'] == 'France', 'geometry'] = Polygons
india.plot()
